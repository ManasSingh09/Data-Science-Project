# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
shoping=pd.read_csv("shopping_trends.csv")

# %%
shoping.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
shoping.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
shoping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
shoping.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
shoping.shape
# Out:
# (3900, 19)

# %%
shoping.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
shoping["Age"].plot(kind = "hist")
plt.title("hist chart of Age")
plt.show()

# %%
shoping["Gender"].value_counts().plot(kind = "bar")
plt.title("bar chart of Gender")
plt.show()

# %%
shoping.groupby("Category")["Purchase Amount (USD)"].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
shoping["Subscription Status"].value_counts().plot(kind = "pie",autopct="%1.2f%%")
plt.title("pie chart of subscription")
# Out:
# Text(0.5, 1.0, 'pie chart of subscription')

# %%
shoping.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
shoping.head(75).plot(x="Previous Purchases", y="Review Rating",kind = "scatter")
plt.title("previous purchase rating review")
plt.show()

# %% [markdown]
# # season wise purchase

# %%
shoping.groupby("Season")["Purchase Amount (USD)"].sum()
# Out:
# Season
# Fall      60018
# Spring    58679
# Summer    55777
# Winter    58607
# Name: Purchase Amount (USD), dtype: int64

# %%
shoping.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
shoping.boxplot(column="Purchase Amount (USD)", by ="Frequency of Purchases",color="green")
plt.title("box plot of purchase amount based of frequency purchases")
plt.show()

# %%
shoping["Preferred Payment Method"].value_counts().sort_values(ascending=False)
# Out:
# Preferred Payment Method
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# Name: count, dtype: int64

# %%
pd.pivot_table(shoping, values = "Purchase Amount (USD)" ,index="Location",columns="Item Purchased",aggfunc="mean").head()
# Out:
# Item Purchased  Backpack       Belt  Blouse      Boots       Coat      Dress  \
# Location
# Alabama             74.0  26.500000    52.0  73.666667  54.500000  55.200000
# Alaska              74.6  76.750000    67.5  56.000000  45.500000  74.500000
# Arizona             48.6  84.500000    61.0        NaN  65.333333  71.000000
# Arkansas            90.0  55.000000    66.0  50.000000  54.250000  62.800000
# California          57.4  61.666667    39.5  62.500000  55.000000  58.428571
#
# Item Purchased     Gloves    Handbag        Hat     Hoodie  ...      Scarf  \
# Location                                                    ...
# Alabama         85.000000  57.666667  76.000000  53.000000  ...  75.333333
# Alaska          66.333333  46.000000  52.666667  56.500000  ...  45.000000
# Arizona         87.000000  58.666667  87.000000  66.666667  ...  53.500000
# Arkansas        64.333333  50.000000  35.000000  55.250000  ...  67.500000
# ...

# %%
shoping.groupby("Size")["Purchase Amount (USD)"].sum()
# Out:
# Size
# L      61667
# M     105167
# S      40468
# XL     25779
# Name: Purchase Amount (USD), dtype: int64

# %%
shoping.groupby("Payment Method")["Purchase Amount (USD)"].sum().sort_values(ascending=False)
# Out:
# Payment Method
# Credit Card      42567
# Venmo            39991
# Cash             38833
# PayPal           37449
# Bank Transfer    37123
# Debit Card       37118
# Name: Purchase Amount (USD), dtype: int64

# %%
shoping.groupby("Discount Applied")["Review Rating"].max()
# Out:
# Discount Applied
# No     5.0
# Yes    5.0
# Name: Review Rating, dtype: float64

# %%
shoping.groupby("Color")["Category"].value_counts()
# Out:
# Color   Category
# Beige   Clothing       65
#         Accessories    44
#         Footwear       24
#         Outerwear      14
# Black   Clothing       81
#                        ..
# White   Outerwear      15
# Yellow  Clothing       75
#         Accessories    56
#         Footwear       30
#         Outerwear      13
# Name: count, Length: 100, dtype: int64

# %%
shoping["Season"].value_counts().plot(kind="bar")
plt.xlabel("season")
plt.ylabel("count")
plt.title("count of purchase in each season")
plt.show()

# %%
shoping["Category"].value_counts().plot(kind = "pie",autopct="%1.2f%%")
plt.title("category wise sales")
plt.show()

# %%
shoping.groupby("Gender")["Purchase Amount (USD)"].sum()
# Out:
# Gender
# Female     75191
# Male      157890
# Name: Purchase Amount (USD), dtype: int64

# %%
shoping["Purchase Amount (USD)"].plot(kind = "hist")
plt.xlabel("USD")
plt.ylabel("frequency")
plt.title("histogram of purchase amount")
plt.show()

# %%
shoping.groupby("Color")["Review Rating"].mean().head(20).plot(kind = "bar")
plt.xlabel("color")
plt.ylabel("main review rating")
plt.title("main review rating for each color")
plt.show()

# %%
shoping.groupby("Payment Method")["Purchase Amount (USD)"].sum().plot(kind="pie",autopct="%1.2f%%")
plt.title("sum of purchase amount by payment method")
plt.show()

# %%
shoping.groupby("Season")["Purchase Amount (USD)"].sum().plot(kind="pie",autopct="%1.2f%%")
plt.title("season wise purchase on pie chart")
plt.show()

# %%
shoping.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
pd.pivot_table(shoping, values="Purchase Amount (USD)",index="Gender",columns="Item Purchased",aggfunc="sum")
# Out:
# Item Purchased  Backpack  Belt  Blouse  Boots  Coat  Dress  Gloves  Handbag  \
# Gender
# Female              2413  3209    4016   3226  2847   3492    2416     3342
# Male                6223  6426    6394   5792  6428   6828    6061     5515
#
# Item Purchased   Hat  Hoodie  ...  Scarf  Shirt  Shoes  Shorts  Skirt  \
# Gender                        ...
# Female          3118    3007  ...   2702   3552   2888    2797   3051
# Male            6257    5760  ...   6859   6780   6352    6636   6351
#
# Item Purchased  Sneakers  Socks  Sunglasses  Sweater  T-shirt
# Gender
# Female              2579   3211        3248     2923     2717
# Male                6056   6041        6401     6539     6531
#
# [2 rows x 25 columns]

# %%
shoping.groupby("Shipping Type")["Purchase Amount (USD)"].sum().sort_values(ascending=Fa
# Out:
# Shipping Type
# 2-Day Shipping    38080
# Express           39067
# Free Shipping     40777
# Next Day Air      37993
# Standard          38233
# Store Pickup      38931
# Name: Purchase Amount (USD), dtype: int64

# %%
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("shopping_trends.csv")

st.title("Shopping Dashboard")

category = st.selectbox("Select Category", df["Category"].unique())

filtered = df[df["Category"] == category]

fig, ax = plt.subplots()
sns.barplot(data=filtered, x="Season", y="Purchase Amount (USD)", ax=ax)
st.pyplot(fig)
# Out:
# DeltaGenerator()

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')
